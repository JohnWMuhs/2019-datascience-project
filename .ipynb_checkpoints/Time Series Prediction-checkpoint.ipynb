# %% [markdown]
# # ARIMA Time Series Prediction
#
# In this notebook, we will use atime-series prediction technique to train and predict CAISO energy consumption data without any external variables. We will use a technique called ARIMA (Auto Regressive Integration Moving Average) prediction technique. This technique takes into account trends, seasonality, and residuals to model a future prediction within a certain confidence interval.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from matplotlib.pylab import rcParams
from scipy import stats
rcParams['figure.figsize'] = 18,6

# %% [markdown]
# ## Import CAISO Data and Split into Train/Test Sets

# %%
df = pd.read_csv('energydata.csv', index_col = 'DateTime', parse_dates=True, usecols = [0,1])
print(df.quantile(0.01))
df = df.where(df > df.quantile(0.01),np.nan)
df = df.fillna(method='ffill')
dfTrain = df[df.index < pd.to_datetime('January 1 2018').tz_localize('US/Pacific')].dropna()
dfTest = df[df.index >= pd.to_datetime('January 1 2018').tz_localize('US/Pacific')].dropna()
dfTest = dfTest[dfTest.index < pd.to_datetime('January 1 2019').tz_localize('US/Pacific')].dropna()
# Out:
# CAISO_HourlyLoad    410302.2
# Name: 0.01, dtype: float64

# %%
# Out:
#                            CAISO_HourlyLoad
# DateTime
# 2015-07-01 00:00:00-07:00           20616.0
# 2015-07-02 00:00:00-07:00          -61202.0
# 2015-07-03 00:00:00-07:00          -40688.0
# 2015-07-04 00:00:00-07:00          -29174.0
# 2015-07-05 00:00:00-07:00           54095.0
# 2015-07-06 00:00:00-07:00            4695.0
# 2015-07-07 00:00:00-07:00          -22566.0
# 2015-07-08 00:00:00-07:00          -17752.0
# 2015-07-09 00:00:00-07:00              73.0
# 2015-07-10 00:00:00-07:00          -22904.0
# 2015-07-11 00:00:00-07:00           -5341.0
# 2015-07-12 00:00:00-07:00           78436.0
# 2015-07-13 00:00:00-07:00          -72777.0
# 2015-07-14 00:00:00-07:00           76047.0
# 2015-07-15 00:00:00-07:00           14806.0
# 2015-07-16 00:00:00-07:00           12639.0
# 2015-07-17 00:00:00-07:00          -78952.0
# 2015-07-18 00:00:00-07:00           14532.0
# 2015-07-19 00:00:00-07:00           96095.0
# 2015-07-20 00:00:00-07:00          -12896.0
# 2015-07-21 00:00:00-07:00          -28209.0
# 2015-07-22 00:00:00-07:00          -16349.0
# 2015-07-23 00:00:00-07:00          -97329.0
# 2015-07-24 00:00:00-07:00           74200.0
# 2015-07-25 00:00:00-07:00          -34525.0
# 2015-07-26 00:00:00-07:00           60409.0
# 2015-07-27 00:00:00-07:00           42935.0
# 2015-07-28 00:00:00-07:00           34151.0
# 2015-07-29 00:00:00-07:00            3180.0
# 2015-07-30 00:00:00-07:00          -11716.0
# ...                                     ...
# 2017-12-02 00:00:00-08:00          -20685.0
# 2017-12-03 00:00:00-08:00           61475.0
# 2017-12-04 00:00:00-08:00            2959.0
# 2017-12-05 00:00:00-08:00            7764.0
# 2017-12-06 00:00:00-08:00            1648.0
# 2017-12-07 00:00:00-08:00           -8149.0
# 2017-12-08 00:00:00-08:00          -35961.0
# 2017-12-09 00:00:00-08:00          -16007.0
# 2017-12-10 00:00:00-08:00           56542.0
# 2017-12-11 00:00:00-08:00            4471.0
# 2017-12-12 00:00:00-08:00            2904.0
# 2017-12-13 00:00:00-08:00           -5687.0
# 2017-12-14 00:00:00-08:00           -1166.0
# 2017-12-15 00:00:00-08:00          -51159.0
# 2017-12-16 00:00:00-08:00          -14073.0
# 2017-12-17 00:00:00-08:00           59433.0
# 2017-12-18 00:00:00-08:00            8256.0
# 2017-12-19 00:00:00-08:00           -3686.0
# 2017-12-20 00:00:00-08:00            7392.0
# 2017-12-21 00:00:00-08:00            -491.0
# 2017-12-22 00:00:00-08:00          -47917.0
# 2017-12-23 00:00:00-08:00          -27352.0
# 2017-12-24 00:00:00-08:00          -14619.0
# 2017-12-25 00:00:00-08:00           39027.0
# 2017-12-26 00:00:00-08:00           18067.0
# 2017-12-27 00:00:00-08:00            -592.0
# 2017-12-28 00:00:00-08:00           -3178.0
# 2017-12-29 00:00:00-08:00          -35084.0
# 2017-12-30 00:00:00-08:00          -16656.0
# 2017-12-31 00:00:00-08:00               NaN
#
# [915 rows x 1 columns]

# %% [markdown]
# ## Test Dataset for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationary(timeseries):
    timewindow = 20
    
    # Calculate Rolling Statistics
    moving_avg = timeseries.rolling(window=timewindow).mean()
    moving_std = timeseries.rolling(window=timewindow).std()
    
    # Plot Rolling Statistics with Raw Data
    plt.plot(timeseries,label='Raw Data')
    plt.plot(moving_avg,label='Rolling Avg ({})'.format(timewindow))
    plt.plot(moving_std,label='Rolling Std ({})'.format(timewindow))
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    #Perform Dicky Fuller Test
    print('Results of Dicky Fuller Test')
    dftest = adfuller(timeseries['CAISO_HourlyLoad'],autolag = 'AIC')
    dfoutput = pd.Series(dftest[0:4],index=['Test Statistic:','p-Value:','#Lags Used','# Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationary(dfTrain.diff().fillna(0))
# Out:
# Results of Dicky Fuller Test
# Test Statistic:        -8.176279e+00
# p-Value:                8.360432e-13
# #Lags Used              2.100000e+01
# # Observations Used     8.930000e+02
# Critical Value (1%)    -3.437694e+00
# Critical Value (5%)    -2.864782e+00
# Critical Value (10%)   -2.568496e+00
# dtype: float64

# %% [markdown]
# ## Decompose Dataset
#
# [Youtube video](https://www.youtube.com/watch?v=cm03ir2Lews)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(dfTrain.diff().fillna(0),freq=7)

# %%
decomp.plot()

# %% [markdown]
# ## Check ACF and PACF Plots

# %% [markdown]
# Add code here from [youtube video](https://www.youtube.com/watch?v=e8Yw4alG16Q) at approximate 29 minutes.

# %% [markdown]
# ## Fit ARIMA

# %% [markdown]
# ## Predict 2018
